# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\adity\OneDrive\Desktop\Great learnings Projects\Indian Education Analysis (Python EDA)\archive\dropout-ratio-2012-2015.csv")
data
# Out:
#            State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0     A & N Islands  2012-13         0.83          0.51          0.68
# 1     A & N Islands  2013-14         1.35          1.06          1.21
# 2     A & N Islands  2014-15         0.47          0.55          0.51
# 3    Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4    Andhra Pradesh  2013-14         4.31          4.39          4.35
# ..              ...      ...          ...           ...           ...
# 105     West Bengal  2013-14         3.44          2.37          2.91
# 106     West Bengal  2014-15         2.13          0.79          1.47
# 107       All India  2012-13         4.68          4.66          4.67
# 108       All India  2013-14         4.53          4.14          4.34
# 109       All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# ...

# %%
data.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total'],
#       dtype='object')

# %%
data.isna()
# Out:
#      State_UT   year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0       False  False         False          False          False
# 1       False  False         False          False          False
# 2       False  False         False          False          False
# 3       False  False         False          False          False
# 4       False  False         False          False          False
# ..        ...    ...           ...            ...            ...
# 105     False  False         False          False          False
# 106     False  False         False          False          False
# 107     False  False         False          False          False
# 108     False  False         False          False          False
# 109     False  False         False          False          False
#
#      Upper Primary_Boys  Upper Primary_Girls  Upper Primary_Total  \
# 0                 False                False                False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    object
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    object
#  6   Upper Primary_Girls  110 non-null    object
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    object
#  9   Secondary _Girls     110 non-null    object
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    object
#  12  HrSecondary_Girls    110 non-null    object
#  13  HrSecondary_Total    110 non-null    object
# dtypes: object(14)
# memory usage: 12.2+ KB

# %%
data_wb=data[data['State_UT']=='West Bengal']
print(data_wb.head())
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# ...

# %%
 data.groupby('State_UT').groups
# Out:
# {'A & N Islands': [0, 1, 2], 'All India': [107, 108, 109], 'Andhra Pradesh': [3, 4, 5], 'Arunachal  Pradesh': [6], 'Arunachal Pradesh': [7, 8], 'Assam': [9, 10, 11], 'Bihar': [12, 13, 14], 'Chandigarh': [15, 16, 17], 'Chhattisgarh': [18, 19, 20], 'Dadra & Nagar Haveli': [21, 22, 23], 'Daman & Diu': [24, 25, 26], 'Delhi': [27, 28, 29], 'Goa': [30, 31, 32], 'Gujarat': [33, 34, 35], 'Haryana': [36, 37, 38], 'Himachal Pradesh': [39, 40, 41], 'Jammu & Kashmir': [42, 43, 44], 'Jharkhand': [45, 46, 47], 'Karnataka': [48, 49, 50], 'Kerala': [51, 52, 53], 'Lakshadweep': [54, 55, 56], 'Madhya  Pradesh': [57], 'Madhya Pradesh': [58, 59], 'Maharashtra': [60, 61, 62], 'Manipur': [63, 64, 65], 'Meghalaya': [66, 67, 68], 'Mizoram': [69, 70, 71], 'Nagaland': [72, 73, 74], 'Odisha': [75, 76, 77], 'Puducherry': [78, 79, 80], 'Punjab': [81, 82, 83], 'Rajasthan': [84, 85, 86], 'Sikkim': [87, 88, 89], 'Tamil  Nadu': [90], 'Tamil Nadu': [91, 92], 'Telangana': [93, 94], 'Tripura': [95, 96, 97], 'Uttar Prad
# ...

# %%
data['Primary_Boys'].values
# Out:
# array(['0.83', '1.35', '0.47', '3.3', '4.31', '6.57', '11.54', '15.84',
#        '11.51', '7.02', '8.19', '16.07', 'NR', '2.38', '0.35', 'NR', 'NR',
#        'NR', '4.24', '1.45', '3.08', 'NR', '1.05', '1.6', 'NR', '1.06',
#        '1.8', 'NR', 'NR', 'NR', 'NR', '0.08', '0.63', '0.21', '0.5',
#        '0.82', '1.48', '0.22', '5.54', '0.51', '0.57', '0.46', '6.8',
#        '5.53', '6.98', '7.36', '6.89', '5.91', '3.4', '2.42', '2.03',
#        'NR', 'NR', 'NR', '2.3', '0', 'NR', '5.75', '9.91', '6.48', '0.88',
#        '0.51', '1.26', '10.24', '17.27', '9.5', '11.32', '11.3', '10.35',
#        '24.27', '12.57', '10.17', '7.11', '19.09', '6.18', '3.63', '2.83',
#        '2.91', '0.25', '0.76', '0.36', '1.99', '1.35', '2.89', '7.2',
#        '7.76', '5.02', '4.78', '5.55', '3.75', '4.02', '0.53', 'NR',
#        '6.04', '2.21', '2.31', '3.63', '1.37', '10.53', '7.91', '9.08',
#        '1.14', '3.28', '4.37', '6.88', '3.44', '2.13', '4.68', '4.53',
#        '4.36'], dtype=object)

# %%
data = data.replace('NR',0)

# %%
data=data.replace('Uppe_r_Primary',0)

# %%
data['Upper Primary_Boys']=data['Upper Primary_Boys'].values.astype(np.float32)
data['Upper Primary_Girls']=data['Upper Primary_Girls'].values.astype(np.float32)

# %%
data['Secondary _Boys']=data['Secondary _Boys'].values.astype(np.float32)
data['Secondary _Girls']=data['Secondary _Girls'].values.astype(np.float32)

data['HrSecondary_Boys']=data['HrSecondary_Boys'].values.astype(np.float32)
data['HrSecondary_Girls']=data['HrSecondary_Girls'].values.astype(np.float32)

# %%
data.describe()
# Out:
#        Upper Primary_Boys  Upper Primary_Girls  Secondary _Boys  \
# count          110.000000           110.000000       110.000000
# mean             3.581909             4.169455        17.162273
# std              3.388699             3.444964         8.931008
# min              0.000000             0.000000         0.000000
# 25%              0.782500             1.580000        11.312500
# 50%              3.120000             3.535000        16.105000
# 75%              5.422500             5.835000        23.012500
# max             19.350000            19.209999        50.090000
#
#        Secondary _Girls  HrSecondary_Boys  HrSecondary_Girls
# count        110.000000        110.000000         110.000000
# mean          16.311457          6.968000           4.979363
# std            9.403942          7.404572           5.468029
# min            0.000000          0.000000           0.000000
# 25%            9.385000          0.057500           0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    object
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    float32
#  6   Upper Primary_Girls  110 non-null    float32
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    float32
#  9   Secondary _Girls     110 non-null    float32
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    float32
#  12  HrSecondary_Girls    110 non-null    float32
#  13  HrSecondary_Total    110 non-null    object
# dtypes: float32(6), object(8)
# memory usage: 9.6+ KB

# %%
years = data_wb['year'].values
years
# Out:
# array(['2012-13', '2013-14', '2014-15'], dtype=object)

# %%
plt.figure(figsize= (35,15))
sns.countplot(data['State_UT'])
# Out:
# <Axes: xlabel='count', ylabel='State_UT'>

# %%
plt.bar(data_wb['Primary_Girls'],data_wb['year'] )
plt.xlabel('Primary_Girls')
plt.ylabel('Year')
plt.title('Year basis Primary_Girls ratio in west bengal')
plt.show()

# %%
plt.bar(data['Secondary _Girls'],data['year'] )
plt.xlabel('Secondary _Girls')
plt.ylabel('Year')
plt.title('Year basis Secondary _Girls ratio')
plt.show()

# %%
plt.bar(data_wb['Primary_Boys'],data_wb['year'] )
plt.xlabel('Primary Boys')
plt.ylabel('Year')
plt.title('Year basis primary boys ratio in west Bengal')
plt.show()

# %%
plt.bar(data_wb['Primary_Girls'],data_wb['year'] )
plt.xlabel('Primary_Girls')
plt.ylabel('Year')
plt.title('Year basis Primary_Girls ratio in west bengal')
plt.show()

# %%
plt.bar(data_wb['Upper Primary_Girls'],data_wb['year'] )
plt.xlabel('Upper Primary_Girls')
plt.ylabel('year')
plt.title('Upper Primary_Girls ratio vs year ')
plt.show()

# %%
plt.hist(data['HrSecondary_Girls'])
# Out:
# (array([52., 25., 18., 11.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.        ,  3.60500002,  7.21000004, 10.81499958, 14.42000008,
#         18.02499962, 21.62999916, 25.2349987 , 28.84000015, 32.44499969,
#         36.04999924]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(data['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(data['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(data['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(data['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(data['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(data['Secondary _Boys'])
# Out:
# <Axes: ylabel='Secondary _Boys'>

# %%
data['HrSecondary_Girls']=data['HrSecondary_Girls'].clip(lower=data['HrSecondary_Girls'].quantile(0.05), upper=data['HrSecondary_Girls'].quantile(0.95))
data['HrSecondary_Boys']=data['HrSecondary_Boys'].clip(lower=data['HrSecondary_Boys'].quantile(0.05), upper=data['HrSecondary_Boys'].quantile(0.95))
data['Upper Primary_Boys']=data['Upper Primary_Boys'].clip(lower=data['Upper Primary_Boys'].quantile(0.05), upper=data['Upper Primary_Boys'].quantile(0.95))
data['Upper Primary_Girls']=data['Upper Primary_Girls'].clip(lower=data['Upper Primary_Girls'].quantile(0.05), upper=data['Upper Primary_Girls'].quantile(0.95))
data['Secondary _Girls']=data['Secondary _Girls'].clip(lower=data['Secondary _Girls'].quantile(0.05), upper=data['Secondary _Girls'].quantile(0.95))
data['Secondary _Boys']=data['Secondary _Boys'].clip(lower=data['Secondary _Boys'].quantile(0.05), upper=data['Secondary _Boys'].quantile(0.95))

# %%
# Outlier detection using boxplots 
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(data['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(data['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(data['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(data['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(data['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(data['Secondary _Boys'])
# Out:
# <Axes: ylabel='Secondary _Boys'>

# %%
sns.pairplot(data,diag_kind='kde')

# %%
girlsT=pd.read_csv(r"C:\Users\adity\OneDrive\Desktop\Great learnings Projects\Indian Education Analysis (Python EDA)\archive\schools-with-girls-toilet-2013-2016.csv")
girlsT
# Out:
#                       State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 0                    All India  2013-14         88.68                   95.98
# 1                    All India  2014-15         91.21                   96.92
# 2                    All India  2015-16         96.95                   99.03
# 3    Andaman & Nicobar Islands  2013-14         89.74                   97.37
# 4    Andaman & Nicobar Islands  2014-15        100.00                  100.00
# ..                         ...      ...           ...                     ...
# 105                Uttarakhand  2014-15         95.43                   98.91
# 106                Uttarakhand  2015-16         96.71                   98.99
# 107                West Bengal  2013-14         80.02                   86.40
# 108                West Bengal  2014-15         91.69                   89.91
# 109                West Bengal  2015-16         98.10                   94.78
#
# ...

# %%
plt.bar(girlsT['All Schools'], girlsT['year'])
# Out:
# <BarContainer object of 110 artists>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    object
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    float64
#  6   Upper Primary_Girls  110 non-null    float64
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    float64
#  9   Secondary _Girls     110 non-null    float64
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    float64
#  12  HrSecondary_Girls    110 non-null    float64
#  13  HrSecondary_Total    110 non-null    object
# dtypes: float64(6), object(8)
# memory usage: 12.2+ KB

# %%
girlsT['Primary_Only']=girlsT['Primary_Only'].values.astype(np.float32)
girlsT['U_Primary_Only']=girlsT['U_Primary_Only'].values.astype(np.float32)
girlsT['Sec_Only']=girlsT['Sec_Only'].values.astype(np.float32)
girlsT['HrSec_Only']=girlsT['HrSec_Only'].values.astype(np.float32)

# %%
# Outlier detection using boxplots 
plt.figure(figsize= (20,15))
plt.subplot(4,4,1)
sns.boxplot(girlsT['Primary_Only'])

plt.subplot(4,4,2)
sns.boxplot(girlsT['U_Primary_Only'])

plt.subplot(4,4,3)
sns.boxplot(girlsT['Sec_Only'])

plt.subplot(4,4,4)
sns.boxplot(girlsT['HrSec_Only'])
# Out:
# <Axes: ylabel='HrSec_Only'>

# %%
girlsT['Primary_Only']=girlsT['Primary_Only'].clip(lower=girlsT['Primary_Only'].quantile(0.05), upper=girlsT['Primary_Only'].quantile(0.95))
girlsT['U_Primary_Only']=girlsT['U_Primary_Only'].clip(lower=girlsT['U_Primary_Only'].quantile(0.05), upper=girlsT['U_Primary_Only'].quantile(0.95))
plt.figure(figsize= (20,15))
plt.subplot(4,4,3)
sns.boxplot(girlsT['Sec_Only'])

plt.subplot(4,4,4)
sns.boxplot(girlsT['HrSec_Only'])
# Out:
# <Axes: ylabel='HrSec_Only'>
